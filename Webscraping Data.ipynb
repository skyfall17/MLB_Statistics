# %%
# !pip install selenium
# !pip install bs4
# Out:
# Requirement already satisfied: selenium in c:\users\zhrac\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: trio~=0.17 in c:\users\zhrac\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\zhrac\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\zhrac\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\zhrac\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: cffi>=1.14 in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: outcome in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\zhrac\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\zhrac\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\zhrac\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\zhrac\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\zhrac\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: bs4 in c:\users\zhrac\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\zhrac\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zhrac\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)

# %%
import selenium
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
weblink = "https://www.spotrac.com/mlb/rankings/2020/salary/"
response = requests.get(weblink)
read_text = response.text

soup = BeautifulSoup(read_text)

#Gathers all of the hyperlinks from the websites  (href = True) and prints the titles of them through the .text
for x in soup.find_all('a', href = True):
    print(x.text.strip())
# Out:
# PREMIUM
# Sign In
# Register
#
# NFL
# Team Salary Caps
# Positional Spending
# Contracts
# Salary Rankings
# Free Agents
#
# Trackers & Tools
# » Market Values
# » Fines/Suspensions
# » IR Tracker
# » Depth Charts Tracker
# » Draft Tracker
# » Options
# » College Tracker
# Best Values
# Transactions
#
# NBA
# Team Cap Tracker
# Positional Payrolls
# Contracts
# Salary Rankings
# Free Agents
#
# Trackers & Tools
# » Depth Charts
# » Options
# » Fines/Suspensions
# » Draft Tracker
# » College Tracker
# » Awards Tracker
# Best Values
#
# Transactions
# » Recent Transactions
# » Extensions
# » Trades
#
# MLB
# Team Payrolls
# Luxury Tax Tracker
# Positional Payrolls
# Contracts
# Salary Rankings
# Free Agents
# Prospects
#
# Trackers & Tools
# » Fines/Suspensions
# » Injured List Tracker
# » Options Tracker
# » Trade Tracker
# » Arbitration Tracker
# Best Values
# Transactions
#
# NHL
# Team Salary Caps
# Positional Payrolls
# Contracts
# Salary Rankings
# Free Agents
#
# Trackers & Tools
# » IR Tracker
# » Options
# » Fines/Suspensions
# » Draft Tracker
# » Trade Tracker
# » College/Junior Team Tracker
# » Country Tracker
# Best Values
# Transactions
#
# EPL
# Team Payrolls
# Positional Payrolls
#
# Salary Rankings
# » Average Salary
# » Weekly Wage
# » Contract Value
# » Transfer Feer
# Transfers
# Free Agents
# Transactions
#
# MLS
# Team Payrolls
# Positional Payrolls
# Salary Rankings
#
# Trackers & Tools
# » Team Caps
# » Draft Tracker
# » College Tracker
# » Trade Tracker
# Transactions
#
# NWSL
# Teams
# Draft
# Federation Players
# NASCAR
# Formula 1
# Tennis
# ATP
# WTA
# USFL
# OTHER
# PHF
# Overtime Elite
# NBAG Ignite
# More
# Spotrac Radio Podcast
# Research & News
# Quick Spots
# PREMIUM
# Sign In
# Register
# Read More
# MLB Teams
# Team Payrolls
# Tax Payrolls
# Positional Spending
# Contracts
# Active Contracts
# Cumulative Cash
# Remaining Cash
# Extensions
# Top Salaries
# Payroll Salaries
# Base Salaries
# Average Salaries
# Contracts
# Career Earnings
# Free Agents
# Prospects
# Tools
# Injured List Tracker
# Market Values
# Options Tracker
# Arbitration Tracker
# Depth Charts Tool
# Draft Tracker
# Fines/Suspensions
# Roster/Payroll Manager
# Best Values
# Transactions
# Teams
# Payroll Tracker
# Positional Spending
# Contracts
# Free Agents
# Prospects
# Transactions
#
# Mike Trout
#
# Gerrit Cole
#
# Max Scherzer
#
# Nolan Arenado
#
# Stephen Strasburg
#
# Zack Greinke
#
# Justin Verlander
#
# Manny Machado
#
# David Price
#
# Clayton Kershaw
#
# Miguel Cabrera
#
# Chris Sale
#
# Jose Altuve
#
# Albert Pujols
#
# Bryce Harper
#
# Mookie Betts
#
# Anthony Rendon
#
# Giancarlo Stanton
#
# Paul Goldschmidt
#
# Jacob deGrom
#
# Jordan Zimmermann
#
# Joey Votto
#
# Robinson Cano
#
# J.D. Martinez
#
# Jason Heyward
#
# Masahiro Tanaka
#
# Freddie Freeman
#
# Wil Myers
#
# Buster Posey
#
# Yu Darvish
#
# Zack Wheeler
#
# Charlie Blackmon
#
# Chris Davis
#
# Eric Hosmer
#
# Josh Donaldson
#
# Johnny Cueto
#
# Shin-Soo Choo
#
# George Springer
#
# Justin Upton
#
# Carlos Santana
#
# Yadier Molina
#
# Justin Turner
#
# Jon Lester
#
# Jake Arrieta
#
# Xander Bogaerts
#
# Hyun-Jin Ryu
#
# Kyle Seager
#
# Patrick Corbin
#
# Mark Melancon
#
# Kris Bryant
#
# Matt Carpenter
#
# Yasmani Grandal
#
# Dallas Keuchel
#
# Kenley Jansen
#
# Cole Hamels
#
# Marcell Ozuna
#
# Jake Odorizzi
#
# Francisco Lindor
#
# Trevor Bauer
#
# Corey Kluber
#
# Aroldis Chapman
#
# Brandon Belt
#
# J.A. Happ
#
# Ryan Braun
#
# Andrew McCutchen
#
# Nathan Eovaldi
#
# Miles Mikolas
#
# Khris Davis
#
# Dexter Fowler
#
# Ian Kennedy
#
# Anthony Rizzo
#
# Craig Kimbrel
#
# Nick Castellanos
#
# Michael Brantley
#
# Yusei Kikuchi
#
# Danny Duffy
#
# Elvis Andrus
#
# Brandon Crawford
#
# Lorenzo Cain
#
# Mike Leake
#
# A.J. Pollock
#
# Charlie Morton
#
# Evan Longoria
#
# Ian Desmond
#
# Andrelton Simmons
#
# Jean Segura
#
# Salvador Perez
#
# Alex Cobb
#
# Jay Bruce
#
# Didi Gregorius
#
# Dee Strange-Gordon
#
# Dustin Pedroia
#
# Zack Britton
#
# Marcus Semien
#
# Tyler Chatwood
#
# Will Smith
#
# Josh Reddick
#
# Randal Grichuk
#
# Jose Abreu
#
# Alex Bregman
# view
# Justin Verlander (SP, HOU)
# view
# Aaron Judge (RF, NYY)
# view
# Cody Bellinger (CF, LAD)
# view
# Sandy Alcantara (SP, MIA)
# view
# Anthony Rizzo (1B, NYY)
# view
# 2023 MLB Free Agents
# view
# MLB Payroll Tracker
# view
# New York Yankees Payroll Table
# view
# MLB Cap Tracker
# view
# MLB Transactions
# Tweets by spotrac
#
# NFL
# NBA
# MLB
# NHL
# MLS
# EPL
# WNBA
# Research
# Podcast
# Back to top
#
#
#
#
#
#
# About Spotrac
# Media Requests
# Advertise with Us
# Contact Us
# Privacy Policy
# Privacy Settings
# Terms of Service
# Accessibility
# Google Privacy
# Spotrac
# MG3 WebWorks

# %% [markdown]
# # Beautiful Soup Implementation

# %%
response = requests.post(weblink, data={'ajax': 'true','mobile': 'false'}).content
read_text = response

soup = BeautifulSoup(read_text)
column_headers = soup.find_all('tr')[0]
column_headers = [i.text.strip().title() for i in column_headers.find_all('th')]
column_headers = column_headers[1:]

baseballPlayers = soup.find_all('tr')[1:]

playerName = []
position = []
age = []
salary = []
team = []

for player in baseballPlayers:
    playerName.append(player.h3.a.text)
    position.append(player.find('td', class_ = 'center small').text.strip())
    salary.append(player.find('span', class_ = 'info').text.strip().replace('$',""))
    team.append(player.find('div', class_ = 'rank-position').text.strip())
    for ages in player.find_all("td", {"class": "center small"}):
        plainText = ages.text.strip()
        
        if(plainText.isnumeric()):
            age.append(plainText)

playerData = pd.DataFrame({"Player": playerName, 'Team': team, 'Age':age,"Position" : position, "Salary": salary})
playerData
# Out:
#                 Player Team Age Position      Salary
# 0           Mike Trout  LAA  28       CF  37,766,667
# 1          Gerrit Cole  NYY  29       SP  36,000,000
# 2         Max Scherzer  WSH  35       SP  35,920,616
# 3        Nolan Arenado  COL  29       3B  35,025,000
# 4    Stephen Strasburg  WSH  31       SP  35,000,000
# ..                 ...  ...  ..      ...         ...
# 995        Riley Smith  ARI  25       RP     563,500
# 996        Keegan Akin  BAL  25       SP     563,500
# 997      Isaac Paredes  DET  21      INF     563,500
# 998        Pavin Smith  ARI  24       1B     563,500
# 999    Thomas Eshelman  BAL  26       RP     563,500
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Pandas Implementation

# %%
#Downside only accesses the first 100 rows
#Since the rest of the data must be accesses by scrolling, if you wanted to use pandas read_html function you would
#have to use selenium to figure the rest out
dfs = pd.read_html(weblink, header = 0)[0].reset_index()
dfs = dfs[['Player','POS','Age','salary']]
dfs.columns = dfs.columns.str.title()
dfs.dropna(inplace = True)
dfs['Team'] = dfs['Player'].str.split(" ", n = 2, expand = True)[2]
dfs['Player'] = dfs['Player'].str[:-4]
dfs
# Out:
#                 Player Pos  Age       Salary  Team
# 0          Mike Trout   CF   28  $37,766,667   LAA
# 1         Gerrit Cole   SP   29  $36,000,000   NYY
# 2        Max Scherzer   SP   35  $35,920,616   WSH
# 3       Nolan Arenado   3B   29  $35,025,000   COL
# 4   Stephen Strasburg   SP   31  $35,000,000   WSH
# ..                 ...  ..  ...          ...   ...
# 95         Will Smith   RP   30  $13,000,000   ATL
# 96       Josh Reddick   RF   33  $13,000,000   HOU
# 97     Randal Grichuk   CF   28  $13,000,000   TOR
# 98         Jose Abreu   1B   33  $12,781,666   CHW
# 99       Alex Bregman   3B   26  $12,666,666   HOU
#
# [100 rows x 5 columns]

# %%
#Want to scrape 25 pages from the 2020 season to compare players and salary
hitData = pd.DataFrame()
link = "https://www.mlb.com/stats/doubles/2020"
for i in range(2, 25):
    r = requests.get(link)
    hitData = pd.concat([hitData, (pd.read_html(r.text, header = 0)[0])])
    link = f"https://www.mlb.com/stats/doubles/2020?page={i}"

hitData = hitData.reset_index()
hitData.drop('index', axis = 1, inplace = True)
hitData
# Out:
#                             PLAYERPLAYER TEAMTEAM  GG  ABAB  RR  HH  \
# 0         1FreddieF FreemanFreeman1B1‌‌‌      ATL  60   214  51  73
# 1            2DominicDo SmithSmith1B2‌‌‌      NYM  50   177  27  56
# 2       3CesarC HernándezHernandez2B3‌‌‌      CLE  58   233  35  66
# 3         4ChristianC WalkerWalker1B4‌‌‌       AZ  57   218  35  59
# 4          5JoseJ IglesiasIglesiasSS5‌‌‌      BAL  39   142  16  53
# ..                                   ...      ...  ..   ...  ..  ..
# 570  486BrianB NavarretoNavarretoC486‌‌‌      MIA   2     5   0   2
# 571         486HectorH NerisNerisP486‌‌‌      PHI  24     0   0   0
# 572    486JohnJ NogowskiNogowski1B486‌‌‌      STL   1     4   0   1
# 573            486AaronA NolaNolaP486‌‌‌      PHI  12     0   0   0
# 574        486EduardoE NúñezNunezX486‌‌‌      NYM   2     2   0   1
#
#      caret-upcaret-down2Bcaret-upcaret-down2B  3B3B  HRHR  RBIRBI  BBBB  SOSO  \
# 0                                          23     1    13      53    45    37
# 1                                          21     1    10      42    14    45
# 2                                          20     0     3      20    24    57
# 3                                          18     1     7      34    19    50
# 4                                          17     0     3      24     3    17
# ..                                        ...   ...   ...     ...   ...   ...
# 570                                         0     0     0       0     0     1
# 571                                         0     0     0       0     0     0
# 572                                         0     0     0       0     0     1
# 573                                         0     0     0       0     0     0
# 574                                         0     0     0       0     0     0
#
#      SBSB  CSCS  AVGAVG  OBPOBP  SLGSLG  OPSOPS
# 0       2     0   0.341   0.462   0.640   1.102
# 1       0     0   0.316   0.377   0.616   0.993
# 2       0     0   0.283   0.355   0.408   0.763
# 3       1     1   0.271   0.333   0.459   0.792
# 4       0     0   0.373   0.400   0.556   0.956
# ..    ...   ...     ...     ...     ...     ...
# 570     0     0   0.400   0.400   0.400   0.800
# 571     0     0   0.000   0.000   0.000   0.000
# 572     0     0   0.250   0.250   0.250   0.500
# 573     0     0   0.000   0.000   0.000   0.000
# 574     1     0   0.500   0.500   0.500   1.000
#
# [575 rows x 18 columns]

# %%
column_headers = ['Player', 'Team', 'Games Played', 'At Bats', 'Runs', 'Hits', 'Doubles', 'Triples', 'Home Runs', 'RBIs',
                 'Walks','Strikeouts', 'Stolen Bases', 'Caught Stealing', 'Batting Average', 'On Base Percentage', 
                 'Slugging Percentage', 'On Base Plus Slugging']

hitData.columns = column_headers

replaceNames = hitData['Player'].str.findall('[A-Z][^A-Z]*')

# df['Player'] = replaceNames
playerNames = []

for names in replaceNames:
    playerNames.append(names[0] + " " + names[2])
    
hitData['Player'] = playerNames
hitData
# Out:
#                Player Team  Games Played  At Bats  Runs  Hits  Doubles  \
# 0     Freddie Freeman  ATL            60      214    51    73       23
# 1       Dominic Smith  NYM            50      177    27    56       21
# 2     Cesar Hernández  CLE            58      233    35    66       20
# 3    Christian Walker   AZ            57      218    35    59       18
# 4       Jose Iglesias  BAL            39      142    16    53       17
# ..                ...  ...           ...      ...   ...   ...      ...
# 570   Brian Navarreto  MIA             2        5     0     2        0
# 571      Hector Neris  PHI            24        0     0     0        0
# 572     John Nogowski  STL             1        4     0     1        0
# 573        Aaron Nola  PHI            12        0     0     0        0
# 574     Eduardo Núñez  NYM             2        2     0     1        0
#
#      Triples  Home Runs  RBIs  Walks  Strikeouts  Stolen Bases  \
# 0          1         13    53     45          37             2
# 1          1         10    42     14          45             0
# 2          0          3    20     24          57             0
# 3          1          7    34     19          50             1
# 4          0          3    24      3          17             0
# ..       ...        ...   ...    ...         ...           ...
# 570        0          0     0      0           1             0
# 571        0          0     0      0           0             0
# 572        0          0     0      0           1             0
# 573        0          0     0      0           0             0
# 574        0          0     0      0           0             1
#
#      Caught Stealing  Batting Average  On Base Percentage  \
# 0                  0            0.341               0.462
# 1                  0            0.316               0.377
# 2                  0            0.283               0.355
# 3                  1            0.271               0.333
# 4                  0            0.373               0.400
# ..               ...              ...                 ...
# 570                0            0.400               0.400
# 571                0            0.000               0.000
# 572                0            0.250               0.250
# 573                0            0.000               0.000
# 574                0            0.500               0.500
#
#      Slugging Percentage  On Base Plus Slugging
# 0                  0.640                  1.102
# 1                  0.616                  0.993
# 2                  0.408                  0.763
# 3                  0.459                  0.792
# 4                  0.556                  0.956
# ..                   ...                    ...
# 570                0.400                  0.800
# 571                0.000                  0.000
# 572                0.250                  0.500
# 573                0.000                  0.000
# 574                0.500                  1.000
#
# [575 rows x 18 columns]

# %%
#Inner join
overallData = pd.merge(playerData, hitData, on = ['Player','Team'], how = 'inner')
overallData['Salary'] = overallData['Salary'].str.replace(',', "").astype(float)
overallData.dtypes
# Out:
# Player                    object
# Team                      object
# Age                       object
# Position                  object
# Salary                   float64
# Games Played               int64
# At Bats                    int64
# Runs                       int64
# Hits                       int64
# Doubles                    int64
# Triples                    int64
# Home Runs                  int64
# RBIs                       int64
# Walks                      int64
# Strikeouts                 int64
# Stolen Bases               int64
# Caught Stealing            int64
# Batting Average          float64
# On Base Percentage       float64
# Slugging Percentage      float64
# On Base Plus Slugging    float64
# dtype: object
